# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"/content/heart_failure_clinical_records_dataset.csv")
df.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# ...

# %%
df.tail()
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 294  62.0        0                        61         1                 38
# 295  55.0        0                      1820         0                 38
# 296  45.0        0                      2060         1                 60
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 294                    1   155000.0               1.1           143    1
# 295                    0   270000.0               1.2           139    0
# 296                    0   742000.0               0.8           138    0
# 297                    0   140000.0               1.4           140    1
# 298                    0   395000.0               1.6           136    1
#
#      smoking  time  DEATH_EVENT
# 294        1   270            0
# ...

# %%
df.dtypes
# Out:
# age                         float64
# anaemia                       int64
# creatinine_phosphokinase      int64
# diabetes                      int64
# ejection_fraction             int64
# high_blood_pressure           int64
# platelets                   float64
# serum_creatinine            float64
# serum_sodium                  int64
# sex                           int64
# smoking                       int64
# time                          int64
# DEATH_EVENT                   int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
df.isnull().sum()
# Out:
# age                         0
# anaemia                     0
# creatinine_phosphokinase    0
# diabetes                    0
# ejection_fraction           0
# high_blood_pressure         0
# platelets                   0
# serum_creatinine            0
# serum_sodium                0
# sex                         0
# smoking                     0
# time                        0
# DEATH_EVENT                 0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [age, anaemia, creatinine_phosphokinase, diabetes, ejection_fraction, high_blood_pressure, platelets, serum_creatinine, serum_sodium, sex, smoking, time, DEATH_EVENT]
# Index: []

# %%
categoricalfeatures =[features for features in df.columns if df[features].dtypes=='object']
categoricalfeatures
# Out:
# []

# %%
numericalfeatures =[features for features in df.columns if df[features].dtypes!='object']
numericalfeatures
# Out:
# ['age',
#  'anaemia',
#  'creatinine_phosphokinase',
#  'diabetes',
#  'ejection_fraction',
#  'high_blood_pressure',
#  'platelets',
#  'serum_creatinine',
#  'serum_sodium',
#  'sex',
#  'smoking',
#  'time',
#  'DEATH_EVENT']

# %%
for col in numericalfeatures:
  print(f"{col} has {df[col].unique()}")
# Out:
# age has [75.    55.    65.    50.    90.    60.    80.    62.    45.    49.
#  82.    87.    70.    48.    68.    53.    95.    58.    94.    85.
#  69.    72.    51.    57.    42.    41.    67.    79.    59.    44.
#  63.    86.    66.    43.    46.    61.    81.    52.    64.    40.
#  60.667 73.    77.    78.    54.    47.    56.   ]
# anaemia has [0 1]
# creatinine_phosphokinase has [ 582 7861  146  111  160   47  246  315  157  123   81  231  981  168
#    80  379  149  125   52  128  220   63  148  112  122   60   70   23
#   249  159   94  855 2656  235  124  571  127  588 1380  553  129  577
#    91 3964   69  260  371   75  607  789  364 7702  318  109   68  250
#   110  161  113 5882  224   92  102  203  336   76   55  280   78   84
#   115   66  897  154  144  133  514   59  156   61  305  898 5209   53
#   328  748 1876  936  292  369  143  754  400   96  737  358  200  248
#   270 1808 1082  719  193 4540  646  281 1548  805  291  482  943  185
# ...

# %% [markdown]
# #¯´ What is the distribution of age among heart failure patients in the dataset

# %%
X=df[df['DEATH_EVENT']==1]
X
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 1    55.0        0                      7861         0                 38
# 2    65.0        0                       146         0                 20
# 3    50.0        1                       111         0                 20
# 4    65.0        1                       160         1                 20
# ..    ...      ...                       ...       ...                ...
# 220  73.0        0                       582         0                 20
# 230  60.0        0                       166         0                 30
# 246  55.0        0                      2017         0                 25
# 262  65.0        1                       258         1                 25
# 266  55.0        0                      1199         0                 20
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
sns.relplot(x=df['age'],y=X.DEATH_EVENT,data=df)

# %% [markdown]
# #´ What is the percentage of male and female patients in the dataset?

# %%
df['sex'].value_counts(normalize=True)
# Out:
# 1    0.648829
# 0    0.351171
# Name: sex, dtype: float64

# %% [markdown]
# #How does the platelet count vary among different age

# %%
plt.scatter(df['platelets'],df['age'])

# %% [markdown]
# Is there a correlation betwenn sodium and creatinine levels in the blood?

# %%
X=df[['serum_creatinine','serum_sodium']]

# %%
X.corr()
# Out:
#                   serum_creatinine  serum_sodium
# serum_creatinine          1.000000     -0.189095
# serum_sodium             -0.189095      1.000000

# %%
#There is correlation between 	serum_creatinine and serum_sodium in the blood levels as one value increases other value decreases

# %%
plt.scatter(df['serum_creatinine'],df['serum_sodium'])

# %% [markdown]
# #How does the prelevance of high bp differ in case of male and fenale patient?

# %%
X=df[df['high_blood_pressure']==1]
X
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0    75.0        0                       582         0                 20
# 5    90.0        1                        47         0                 40
# 9    80.0        1                       123         0                 35
# 10   75.0        1                        81         0                 38
# 11   62.0        0                       231         0                 25
# ..    ...      ...                       ...       ...                ...
# 255  52.0        1                       191         1                 30
# 257  58.0        0                       132         1                 38
# 270  44.0        0                       582         1                 30
# 275  45.0        0                       582         0                 38
# 294  62.0        0                        61         1                 38
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
X.sex.value_counts()
# Out:
# 1    61
# 0    44
# Name: sex, dtype: int64

# %%
#Bp is high more in case of males as compared to females

# %% [markdown]
# #>What is the relationship between smoking habits and occurence of heart failure?

# %%
X=df[df['smoking']==1]
X
# Out:
#       age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 2    65.0        0                       146         0                 20
# 5    90.0        1                        47         0                 40
# 7    60.0        1                       315         1                 60
# 9    80.0        1                       123         0                 35
# 10   75.0        1                        81         0                 38
# ..    ...      ...                       ...       ...                ...
# 292  52.0        0                       190         1                 38
# 293  63.0        1                       103         1                 35
# 294  62.0        0                        61         1                 38
# 297  45.0        0                      2413         0                 38
# 298  50.0        0                       196         0                 45
#
#      high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# ...

# %%
X.DEATH_EVENT.value_counts()
# Out:
# 0    66
# 1    30
# Name: DEATH_EVENT, dtype: int64

# %%
#The people who are smoking are less likely to cause death

# %% [markdown]
# #Ar5 th5r5 any not"c5abl5 patt5rns "n th5 d"str"but"on o/ d5ath 5v5nts across d"//5r5nt ag5 groups<

# %%
plt.scatter(df['age'],df['DEATH_EVENT'])

# %% [markdown]
# #> Is th5r5 any s"gn"/"cant d"//5r5nc5 "n 55ct"on /ract"on b5tw55n pat"5nts w"th and w"thout d"ab5t5s<

# %%
X=df[df['diabetes']==1]
X.head()
# Out:
#      age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 4   65.0        1                       160         1                 20
# 7   60.0        1                       315         1                 60
# 19  48.0        1                       582         1                 55
# 21  65.0        1                       128         1                 30
# 23  53.0        0                        63         1                 60
#
#     high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 4                     0   327000.0               2.7           116    0
# 7                     0   454000.0               1.1           131    1
# 19                    0    87000.0               1.9           121    0
# 21                    1   297000.0               1.6           136    0
# 23                    0   368000.0               0.8           135    1
#
#     smoking  time  DEATH_EVENT
# 4         0     8            1
# ...

# %%
X.ejection_fraction
# Out:
# 4      20
# 7      60
# 19     55
# 21     30
# 23     60
#        ..
# 290    55
# 292    38
# 293    35
# 294    38
# 296    60
# Name: ejection_fraction, Length: 125, dtype: int64

# %%
plt.scatter(df['diabetes'],df['ejection_fraction'])

# %%
#Ejection fraction is more in case of non- diabetes patient

# %%
plt.scatter(df['serum_creatinine'],df['DEATH_EVENT'])
